# %% [markdown]
# # euclidean disatnce
#
# # summation n to i=n(qi-pi)^2 whole squareroot

# %% [markdown]
# # q= (1,3) q1,q2
# # p =(2,5) p1,p2
#
# # euclidean distance =(q1-p1)**2 + (q2-p2)**2 whole squareroot

# %%
from math import sqrt

plot1 = [1,3]
plot2 = [2,5]

euclidean_distance = sqrt((plot1[0]-plot2[0])**2 + (plot1[1]-plot2[1])**2)
print(euclidean_distance)
# Out:
# 2.23606797749979

# %%
import numpy as np
from math import sqrt
import matplotlib.pyplot as plt
import warnings
from matplotlib import style
from collections import Counter
style.use('fivethirtyeight')

# %%
# k class list of list called as features two dimensional features and "r" which is our label it should same number as features 
# new_features =[5,7]

#dataset = {'k':[[1,2],[2,3],[3,1]], 'r':[[6,5],[7,7],[8,6]]}
#new_features =[5,7]

# %%
for i in dataset:
    for ii in dataset[i]:
        plt.scatter(ii[0], ii[1], s=100, color=i )

# %%
# above is same as this 
# this is one liner for loop

[[plt.scatter(ii[0], ii[1], s=100, color=i ) for ii in dataset[i]] for i in dataset]
# Out:
# [[<matplotlib.collections.PathCollection at 0x16effe52be0>,
#   <matplotlib.collections.PathCollection at 0x16effe52fd0>,
#   <matplotlib.collections.PathCollection at 0x16effe603a0>],
#  [<matplotlib.collections.PathCollection at 0x16effe60790>,
#   <matplotlib.collections.PathCollection at 0x16effda0250>,
#   <matplotlib.collections.PathCollection at 0x16effd4ee50>]]

# %%
plt.show()

# %%
# this to plot the new features along with the one before 

[[plt.scatter(ii[0], ii[1], s=100, color=i ) for ii in dataset[i]] for i in dataset]
plt.scatter(new_features[0],new_features[1], s= 150, color='g')
plt.show()

# %%
# define k nearest #

def k_nearest_neighbors(data, predict, k=3):
    if len(data) >=k:
        warnings.warn(' k is lesser than the class labels you idiot')
        
    # special knn algos
    #knnalgos
    # we need to find out distance betwween each data point find out who is the closest data point to this we need compare predictioon with all other data points
    #  radius look with a certain radius reduces calculation time by looking inside the radius and outside the radius
    distances = []
    for group in data:
        for features in data[group]:
            
            #euclidean_distance = sqrt((plot1[0]-plot2[0])**2 + (plot1[1]-plot2[1])**2)
            euclidean_distance =  np.linalg.norm(np.array(features)-np.array(predict))
            distances.append([euclidean_distance, group])# first item inthe list is distance second is group so that we can sort
    votes = [i[1] for i in sorted(distances) [:k] ]
    print(Counter(votes).most_common(1))
    vote_result = Counter(votes).most_common(1)[0][0]
    return vote_result

# %%
result = k_nearest_neighbors(dataset, new_features, k=3)
print(result)
# Out:
# [('r', 3)]
# r

# %%
[[plt.scatter(ii[0], ii[1], s=100, color=i ) for ii in dataset[i]] for i in dataset]
plt.scatter(new_features[0],new_features[1], s= 1500, color=result)
plt.show()
